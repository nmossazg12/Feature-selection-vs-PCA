# %% [markdown]
# <a href="https://colab.research.google.com/github/nmossazg12/Feature-selection-vs-PCA/blob/main/SocioenvironmentalGeometry/code/Gorilla2BIDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Gorilla Info: <br>
# Project: SocioenvironmentalConceptGeometry <br>
# Version: 9 <br>
# Account: Roberto Vargas (robertov@andrew.cmu.edu)

# %%
#Load relevant libraries and install dependencies
import pandas as pd
import numpy as np

# %%
# function to convert values in the pivot values from list to float for PRaM and SPaM

def convert_to_float(x):
    if isinstance(x, list):
        return float(x[0]) # assuming there is only one value in the list
    else:
        return x

# %%
#Load Data:

#QUESTIONAIRRES:
#Demographics
url = 'https://raw.githubusercontent.com/ExCaLBBR/ExCaLBBR_Projects/main/SocioenvironmentalGeometry/data/raw/raw_demographic.csv'
df_demographic = pd.read_csv(url)

#Ethnic Identity
url ='https://raw.githubusercontent.com/ExCaLBBR/ExCaLBBR_Projects/main/SocioenvironmentalGeometry/data/raw/raw_questionnaire_EthnicIdentity.csv'
df_EthId = pd.read_csv(url)

#Multidimensional Inventory of Black Identity
url = 'https://raw.githubusercontent.com/ExCaLBBR/ExCaLBBR_Projects/main/SocioenvironmentalGeometry/data/raw/raw_questionnaire_MIBI.csv'
df_MIBI = pd.read_csv(url)

#News Consumption
url = 'https://raw.githubusercontent.com/ExCaLBBR/ExCaLBBR_Projects/main/SocioenvironmentalGeometry/data/raw/raw_questionnaire_NewsConsumption.csv'
df_News = pd.read_csv(url)

#Gender/Racial Discrimination
url = 'https://raw.githubusercontent.com/ExCaLBBR/ExCaLBBR_Projects/main/SocioenvironmentalGeometry/data/raw/raw_questionnaire_GR-Discrim.csv'
df_GRDiscrim = pd.read_csv(url)

#Concept Exposure
url = 'https://raw.githubusercontent.com/ExCaLBBR/ExCaLBBR_Projects/main/SocioenvironmentalGeometry/data/raw/raw_questionnaire_ConceptExposure.csv'
df_ConExposure = pd.read_csv(url)

#Concept Feeling
url = 'https://raw.githubusercontent.com/ExCaLBBR/ExCaLBBR_Projects/main/SocioenvironmentalGeometry/data/raw/raw_questionnaire_ConceptFeeling.csv'
df_ConFeeling = pd.read_csv(url)

#Concept Interaction
url = 'https://raw.githubusercontent.com/ExCaLBBR/ExCaLBBR_Projects/main/SocioenvironmentalGeometry/data/raw/raw_questionnaire_ConceptInteraction.csv'
df_ConInteraction = pd.read_csv(url)

#Social Dominance Orientation
url = 'https://raw.githubusercontent.com/ExCaLBBR/ExCaLBBR_Projects/main/SocioenvironmentalGeometry/data/raw/raw_questionnaire_SDO.csv'
df_SDO = pd.read_csv(url)


#TASKS:
#PRaM
url = 'https://github.com/ExCaLBBR/ExCaLBBR_Projects/raw/main/SocioenvironmentalGeometry/data/raw/raw_task_PRaM.csv.gz'
df_taskPRaM = pd.read_csv(url, compression='gzip')

#SpAM
url = 'https://raw.githubusercontent.com/ExCaLBBR/ExCaLBBR_Projects/main/SocioenvironmentalGeometry/data/raw/raw_task_SpAM.csv'
df_taskSpAM = pd.read_csv(url)

#Default values 
url = 'https://raw.githubusercontent.com/ExCaLBBR/ExCaLBBR_Projects/main/SocioenvironmentalGeometry/data/raw/defaultCoordinates.csv'
df_default_values = pd.read_csv(url)
# Out:
# <ipython-input-3-a337d915c2c7>:44: DtypeWarning: Columns (0,35,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_taskPRaM = pd.read_csv(url, compression='gzip')
# <ipython-input-3-a337d915c2c7>:48: DtypeWarning: Columns (0,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_taskSpAM = pd.read_csv(url)

# %%
#Isolate relevant columns: Demographics
include = ['Participant Completion Code', 'Question Key', 'Response']
#df_demographic = df_demographic[~df_demographic['Event Index'].str.contains('END OF FILE', na=True)]
df_demographic.drop(columns=df_demographic.columns.difference(include), inplace=True)
mask = df_demographic['Question Key'].str.contains('BEGIN QUESTIONNAIRE', na=True) | df_demographic['Question Key'].str.contains('END QUESTIONNAIRE', na=True) | df_demographic['Question Key'].str.contains('quantised', na=True) | df_demographic['Question Key'].str.contains('response-2', na=True)
df_demographic = df_demographic[~mask]
df_demographic = df_demographic.dropna()
#display(df_demographic)

#Isolate relevant columns: Ethnic Identity
include = ['Participant Completion Code', 'Question Key', 'Response']
#df_EthId = df_EthId[~df_EthId['Event Index'].str.contains('END OF FILE', na=True)]
df_EthId.drop(columns=df_EthId.columns.difference(include), inplace=True)
mask = df_EthId['Question Key'].str.contains('BEGIN QUESTIONNAIRE', na=True) | df_EthId['Question Key'].str.contains('END QUESTIONNAIRE', na=True)
df_EthId = df_EthId[~mask]
df_EthId = df_EthId.dropna()
#display(df_EthId)

#Isolate relevant columns: Multidimensional Inventory of Black Identity
include = ['Participant Completion Code', 'Question Key', 'Response']
#df_MIBI = df_MIBI[~df_MIBI['Event Index'].str.contains('END OF FILE', na=True)]
df_MIBI.drop(columns=df_MIBI.columns.difference(include), inplace=True)
mask = df_MIBI['Question Key'].str.contains('BEGIN QUESTIONNAIRE', na=True) | df_MIBI['Question Key'].str.contains('END QUESTIONNAIRE', na=True)
df_MIBI = df_MIBI[~mask]
df_MIBI = df_MIBI.dropna()
#display(df_MIBI)

#Isolate relevant columns: News Consumption
include = ['Participant Completion Code', 'Question Key', 'Response']
#df_News = df_News[~df_News['Event Index'].str.contains('END OF FILE', na=True)]
df_News.drop(columns=df_News.columns.difference(include), inplace=True)
mask = df_News['Question Key'].str.contains('BEGIN QUESTIONNAIRE', na=True) | df_News['Question Key'].str.contains('END QUESTIONNAIRE', na=True)
df_News = df_News[~mask]
df_News = df_News.dropna()
#display(df_News)

#Isolate relevant columns: Gender/Racial Discrimination
include = ['Participant Completion Code', 'Question Key', 'Response']
#df_GRDiscrim = df_GRDiscrim[~df_GRDiscrim['Event Index'].str.contains('END OF FILE', na=True)]
df_GRDiscrim.drop(columns=df_GRDiscrim.columns.difference(include), inplace=True)
mask = df_GRDiscrim['Question Key'].str.contains('BEGIN QUESTIONNAIRE', na=True) | df_GRDiscrim['Question Key'].str.contains('END QUESTIONNAIRE', na=True)
df_GRDiscrim = df_GRDiscrim[~mask]
df_GRDiscrim = df_GRDiscrim.dropna()
#display(df_GRDiscrim)

#Isolate relevant columns: Concept Exposure
include = ['Participant Completion Code', 'Question Key', 'Response']
#df_ConExposure = df_ConExposure[~df_ConExposure['Event Index'].str.contains('END OF FILE', na=True)]
df_ConExposure.drop(columns=df_ConExposure.columns.difference(include), inplace=True)
mask = df_ConExposure['Question Key'].str.contains('BEGIN QUESTIONNAIRE', na=True) | df_ConExposure['Question Key'].str.contains('END QUESTIONNAIRE', na=True)
df_ConExposure = df_ConExposure[~mask]
df_ConExposure = df_ConExposure.dropna()
#display(df_ConExposure)

#Isolate relevant columns: Concept Feeling
include = ['Participant Completion Code', 'Question Key', 'Response']
#df_ConFeeling = df_ConFeeling[~df_ConFeeling['Event Index'].str.contains('END OF FILE', na=True)]
df_ConFeeling.drop(columns=df_ConFeeling.columns.difference(include), inplace=True)
mask = df_ConFeeling['Question Key'].str.contains('BEGIN QUESTIONNAIRE', na=True) | df_ConFeeling['Question Key'].str.contains('END QUESTIONNAIRE', na=True)
df_ConFeeling = df_ConFeeling[~mask]
df_ConFeeling = df_ConFeeling.dropna()
#display(df_ConFeeling)

#Isolate relevant columns: Concept Interaction
include = ['Participant Completion Code', 'Question Key', 'Response']
#df_ConInteraction = df_ConInteraction[~df_ConInteraction['Event Index'].str.contains('END OF FILE', na=True)]
df_ConInteraction.drop(columns=df_ConInteraction.columns.difference(include), inplace=True)
mask = df_ConInteraction['Question Key'].str.contains('BEGIN QUESTIONNAIRE', na=True) | df_ConInteraction['Question Key'].str.contains('END QUESTIONNAIRE', na=True)
df_ConInteraction = df_ConInteraction[~mask]
df_ConInteraction = df_ConInteraction.dropna()
#display(df_ConInteraction)

#Isolate relevant columns: Social Dominance Orientation
include = ['Participant Completion Code', 'Question Key', 'Response']
#df_SDO = df_SDO[~df_SDO['Event Index'].str.contains('END OF FILE', na=True)]
df_SDO.drop(columns=df_SDO.columns.difference(include), inplace=True)
mask = df_SDO['Question Key'].str.contains('BEGIN QUESTIONNAIRE', na=True) | df_SDO['Question Key'].str.contains('END QUESTIONNAIRE', na=True)
df_SDO = df_SDO[~mask]
df_SDO = df_SDO.dropna()
#display(df_SDO)

#Isolate relevant columns: PRaM
include = ['Participant Completion Code', 'Zone Name', 'conceptA', 'conceptB', 'Response']
df_taskPRaM.drop(columns=df_taskPRaM.columns.difference(include), inplace=True)
mask = df_taskPRaM['Zone Name'].str.contains('Likert', na=True)
df_taskPRaM = df_taskPRaM[mask]
df_taskPRaM = df_taskPRaM.dropna()
df_taskPRaM.drop(columns=['Zone Name'], inplace=True)
df_taskPRaM['Pair'] = df_taskPRaM['conceptA'] + '-' + df_taskPRaM['conceptB']
df_taskPRaM.drop(columns=['conceptA', 'conceptB'], inplace=True)
# display(df_taskPRaM)

# #Isolate relevant columns: SpAM
# include = ['Participant Completion Code', 'Zone Name', 'Zone Type', 'Response']
# df_taskSpAM = df_taskSpAM[:-1]
# mask = df_taskSpAM['Trial Number'].str.contains('BEGIN TASK', na=True) | df_taskSpAM['Trial Number'].str.contains('END TASK', na=True)
# df_taskSpAM = df_taskSpAM[~mask]
# df_taskSpAM.drop(columns=df_taskSpAM.columns.difference(include), inplace=True)
# mask = df_taskSpAM['Zone Type'].str.contains('drag_and_drop_main', na=True) | df_taskSpAM['Zone Name'].str.contains('Zone10', na=True) 
# df_taskSpAM = df_taskSpAM[mask]
# df_taskSpAM.drop(columns=['Zone Type'], inplace=True)
# df_taskSpAM['Zone Name'] = df_taskSpAM['Zone Name'].replace(['conceptA', 'conceptB', 'conceptC', 'conceptD', 'conceptE', 'conceptF', 'conceptG'], ['Police', 'Firefighter', 'Neighbors', 'Conservatives', 'Liberals', 'Healthcare', 'Voting'])
# df_taskSpAM = df_taskSpAM.dropna()
# #display(df_taskSpAM)

#Isolate relevant columns: Default values
include = ['Zone Name', 'Zone Type', 'Response']
df_default_values = df_default_values[:-1]
df_default_values.drop(columns=df_default_values.columns.difference(include), inplace=True)
mask = df_default_values['Zone Type'].str.contains('drag_and_drop_main', na=True) | df_default_values['Zone Name'].str.contains('Zone10', na=True) 
df_default_values = df_default_values[mask]
df_default_values.drop(columns=['Zone Type'], inplace=True)
df_default_values['Zone Name'] = df_default_values['Zone Name'].replace(['conceptA', 'conceptB', 'conceptC', 'conceptD', 'conceptE', 'conceptF', 'conceptG'], ['Police', 'Firefighter', 'Neighbors', 'Conservatives', 'Liberals', 'Healthcare', 'Voting'])
df_default_values = df_default_values.dropna()
# display(df_default_values)
# Out:
# <ipython-input-4-51e3b650cfa6>:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_taskPRaM.drop(columns=['Zone Name'], inplace=True)
# <ipython-input-4-51e3b650cfa6>:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_taskPRaM['Pair'] = df_taskPRaM['conceptA'] + '-' + df_taskPRaM['conceptB']
# <ipython-input-4-51e3b650cfa6>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_taskPRaM.drop(columns=['conceptA', 'conceptB'], inplace=True)
# <ipython-input-4-51e3b650cfa6>:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_default_values.drop(columns=df_default_values.columns.difference(include), inplace=True)

# %%
#SpAM
url = 'https://raw.githubusercontent.com/ExCaLBBR/ExCaLBBR_Projects/main/SocioenvironmentalGeometry/data/raw/raw_task_SpAM.csv'
df_taskSpAM = pd.read_csv(url)

#Isolate relevant columns: SpAM
include = ['Participant Completion Code', 'Zone Name', 'Zone Type', 'Response']
df_taskSpAM = df_taskSpAM[:-1]
mask = df_taskSpAM['Trial Number'].str.contains('BEGIN TASK', na=True) | df_taskSpAM['Trial Number'].str.contains('END TASK', na=True)
df_taskSpAM = df_taskSpAM[~mask]
df_taskSpAM.drop(columns=df_taskSpAM.columns.difference(include), inplace=True)
mask = df_taskSpAM['Zone Type'].str.contains('drag_and_drop_main', na=True) | df_taskSpAM['Zone Name'].str.contains('Zone10', na=True) 
df_taskSpAM = df_taskSpAM[mask]
df_taskSpAM.drop(columns=['Zone Type'], inplace=True)
df_taskSpAM['Zone Name'] = df_taskSpAM['Zone Name'].replace(['conceptA', 'conceptB', 'conceptC', 'conceptD', 'conceptE', 'conceptF', 'conceptG'], ['Police', 'Firefighter', 'Neighbors', 'Conservatives', 'Liberals', 'Healthcare', 'Voting'])
df_taskSpAM = df_taskSpAM.dropna()

# df_taskSpAM = df_taskSpAM.groupby(['Participant Completion Code', 'Zone Name'])['Response'].agg(list).reset_index()
# df_taskSpAM = df_taskSpAM.groupby(['Participant Completion Code', ['Zone Name']])['Response'].agg(list).reset_index()
df_taskSpAM = df_taskSpAM.groupby(['Participant Completion Code', 'Zone Name'])['Response'].agg(' '.join).reset_index()
df_taskSpAM = df_taskSpAM.pivot(index='Participant Completion Code', columns=['Zone Name'], values='Response')
# display(df_taskSpAM)
# Out:
# <ipython-input-5-3bdd359b8de2>:3: DtypeWarning: Columns (0,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_taskSpAM = pd.read_csv(url)
# Zone Name                                                                Anger  \
# Participant Completion Code
# aaqmxl                             464px Top, 498px Left 505px Top, 498px Left
# acogtt                               119px Top, 22px Left 111px Top, 31px Left
# adixob                                                   116px Top, 142px Left
# adusps                             156px Top, 297px Left 162px Top, 114px Left
# adxtsl                                                   364px Top, 305px Left
# ...                                                                        ...
# zoafdf                                                   100px Top, 238px Left
# zotpxg                       177px Top, 769px Left 165px Top, 761px Left 20...
# zuidyy                              252px Top, 144px Left 71px Top, 142px Left
# zxbwkz                       55px Top, 382px Left 49px Top, 381px Left 48px...
# zymjlf                       763px Top, 831px Left 864px Top, 805px Left 82...
#
# Zone Name                                                        Conservatives  \
# Participant Completion Code
# aaqmxl                       233px Top, 939px Left 238px Top, 935px Left 22...
# acogtt                                                    439px Top, 21px Left
# adixob                                                                     NaN
# adusps                                                   114px Top, 599px Left
# adxtsl                                                                     NaN
# ...                                                                        ...
# zoafdf                                                    11px Top, 443px Left
# zotpxg                       165px Top, 325px Left 178px Top, 222px Left 21...
# zuidyy                                                                     NaN
# zxbwkz                               50px Top, 649px Left 49px Top, 654px Left
# zymjlf                       117px Top, 802px Left 93px Top, 804px Left 66p...
#
# Zone Name                                                                 Fear  \
# Participant Completion Code
# aaqmxl                                                   175px Top, 320px Left
# acogtt                                                    175px Top, 24px Left
# adixob                                                    54px Top, 142px Left
# adusps                             152px Top, 378px Left 127px Top, 220px Left
# adxtsl                       248px Top, 390px Left 244px Top, 224px Left 18...
# ...                                                                        ...
# zoafdf                                                   172px Top, 500px Left
# zotpxg                             293px Top, 230px Left 191px Top, 135px Left
# zuidyy                               132px Top, 25px Left 139px Top, 27px Left
# zxbwkz                                                   197px Top, 275px Left
# zymjlf                             667px Top, 421px Left 200px Top, 939px Left
#
# Zone Name                                                          Firefighter  \
# Participant Completion Code
# aaqmxl                             233px Top, 496px Left 108px Top, 491px Left
# acogtt                                                                     NaN
# adixob                                                                     NaN
# adusps                       45px Top, 53px Left 52px Top, 6px Left 84px To...
# adxtsl                       463px Top, 313px Left 444px Top, -14px Left 33...
# ...                                                                        ...
# zoafdf                                                    44px Top, 420px Left
# zotpxg                       92px Top, 321px Left 174px Top, 437px Left 19p...
# zuidyy                       44px Top, 44px Left 39px Top, 29px Left 24px T...
# zxbwkz                             382px Top, 398px Left 381px Top, 403px Left
# zymjlf                       194px Top, 731px Left 197px Top, 1298px Left 8...
#
# Zone Name                                                           Healthcare  \
# Participant Completion Code
# aaqmxl                                                   490px Top, 181px Left
# acogtt                                                                     NaN
# adixob                                 280px Top, 22px Left 70px Top, 6px Left
# adusps                                                    290px Top, -5px Left
# adxtsl                                386px Top, 87px Left 539px Top, 7px Left
# ...                                                                        ...
# zoafdf                             334px Top, 398px Left 285px Top, 481px Left
# zotpxg                       290px Top, 563px Left 289px Top, 563px Left 28...
# zuidyy                                                                     NaN
# zxbwkz                               428px Top, 17px Left 66px Top, 530px Left
# zymjlf                       755px Top, 1265px Left 855px Top, 1218px Left ...
#
# Zone Name                                                          Immigration  \
# Participant Completion Code
# aaqmxl                                                    216px Top, 61px Left
# acogtt                                                                     NaN
# adixob                                43px Top, 28px Left 48px Top, 131px Left
# adusps                                                    62px Top, 454px Left
# adxtsl                                                                     NaN
# ...                                                                        ...
# zoafdf                                                    94px Top, 457px Left
# zotpxg                             269px Top, 462px Left 287px Top, 446px Left
# zuidyy                               371px Top, 31px Left 369px Top, 29px Left
# zxbwkz                                                    38px Top, 275px Left
# zymjlf                       29px Top, 1075px Left 53px Top, 1087px Left 14...
#
# Zone Name                                                                  Joy  \
# Participant Completion Code
# aaqmxl                       377px Top, 308px Left 394px Top, 329px Left 36...
# acogtt                                                                     NaN
# adixob                                                    124px Top, 29px Left
# adusps                               170px Top, 292px Left 71px Top, 60px Left
# adxtsl                       332px Top, 34px Left 333px Top, 29px Left 327p...
# ...                                                                        ...
# zoafdf                                                   104px Top, 249px Left
# zotpxg                                                   408px Top, 592px Left
# zuidyy                               306px Top, -2px Left 295px Top, 30px Left
# zxbwkz                                                   114px Top, 774px Left
# zymjlf                       294px Top, 1260px Left 413px Top, 1574px Left ...
#
# Zone Name                                                             Liberals  \
# Participant Completion Code
# aaqmxl                             256px Top, 148px Left 277px Top, 180px Left
# acogtt                                                    190px Top, 34px Left
# adixob                                                     89px Top, 12px Left
# adusps                                                   124px Top, 516px Left
# adxtsl                       43px Top, 293px Left 40px Top, 290px Left 46px...
# ...                                                                        ...
# zoafdf                                                   457px Top, 307px Left
# zotpxg                       285px Top, 350px Left 275px Top, 327px Left 30...
# zuidyy                               489px Top, 16px Left 176px Top, 24px Left
# zxbwkz                                                   121px Top, 278px Left
# zymjlf                             83px Top, 1279px Left 46px Top, 1328px Left
#
# Zone Name                                                             Love  \
# Participant Completion Code
# aaqmxl                                               186px Top, 779px Left
# acogtt                                                                 NaN
# adixob                                                106px Top, 16px Left
# adusps                          173px Top, 300px Left 54px Top, 148px Left
# adxtsl                                                                 NaN
# ...                                                                    ...
# zoafdf                                               337px Top, 349px Left
# zotpxg                                               406px Top, 458px Left
# zuidyy                                                408px Top, 23px Left
# zxbwkz                         276px Top, 754px Left 285px Top, 777px Left
# zymjlf                       249px Top, 1344px Left 230px Top, 1407px Left
#
# Zone Name                                                            Neighbors  \
# Participant Completion Code
# aaqmxl                       199px Top, 442px Left 324px Top, 496px Left 37...
# acogtt                                                    313px Top, 28px Left
# adixob                                                     71px Top, 38px Left
# adusps                             287px Top, 319px Left 297px Top, 274px Left
# adxtsl                             201px Top, 479px Left 427px Top, 368px Left
# ...                                                                        ...
# zoafdf                                                   253px Top, 532px Left
# zotpxg                             121px Top, 243px Left 426px Top, 711px Left
# zuidyy                             375px Top, 154px Left 108px Top, 141px Left
# zxbwkz                       113px Top, 263px Left 124px Top, 276px Left 19...
# zymjlf                       313px Top, 1204px Left 304px Top, 1498px Left ...
#
# Zone Name                                                               Police  \
# Participant Completion Code
# aaqmxl                             199px Top, 494px Left 200px Top, 491px Left
# acogtt                                                    251px Top, 19px Left
# adixob                                                    88px Top, 150px Left
# adusps                                                   305px Top, 513px Left
# adxtsl                       476px Top, 438px Left 483px Top, 83px Left 479...
# ...                                                                        ...
# zoafdf                                                   398px Top, 445px Left
# zotpxg                       174px Top, 597px Left 186px Top, 521px Left 17...
# zuidyy                               104px Top, 144px Left 56px Top, 25px Left
# zxbwkz                             409px Top, 543px Left 425px Top, 404px Left
# zymjlf                       558px Top, 1034px Left 700px Top, 1033px Left ...
#
# Zone Name                                                             Religion  \
# Participant Completion Code
# aaqmxl                                                   301px Top, 852px Left
# acogtt                                                    324px Top, 28px Left
# adixob                                                   111px Top, 159px Left
# adusps                                                   277px Top, 715px Left
# adxtsl                                                                     NaN
# ...                                                                        ...
# zoafdf                                                   394px Top, 541px Left
# zotpxg                       165px Top, 674px Left 172px Top, 655px Left 16...
# zuidyy                                                      9px Top, 24px Left
# zxbwkz                                                    33px Top, 773px Left
# zymjlf                       353px Top, 723px Left 361px Top, 804px Left 33...
#
# Zone Name                                                              Sadness  \
# Participant Completion Code
# aaqmxl                                                   112px Top, 294px Left
# acogtt                                                                     NaN
# adixob                                                    81px Top, 137px Left
# adusps                             191px Top, 290px Left 105px Top, 132px Left
# adxtsl                                                                     NaN
# ...                                                                        ...
# zoafdf                                                   179px Top, 244px Left
# zotpxg                             362px Top, 133px Left 293px Top, 209px Left
# zuidyy                                                    253px Top, 25px Left
# zxbwkz                             191px Top, 763px Left 204px Top, 772px Left
# zymjlf                       282px Top, 564px Left 565px Top, 409px Left 51...
#
# Zone Name                                                              Science  \
# Participant Completion Code
# aaqmxl                       333px Top, 149px Left 411px Top, 182px Left 40...
# acogtt                                                    514px Top, 15px Left
# adixob                                                    116px Top, 25px Left
# adusps                                                    336px Top, 47px Left
# adxtsl                              520px Top, 151px Left 564px Top, 90px Left
# ...                                                                        ...
# zoafdf                                                   525px Top, 625px Left
# zotpxg                       293px Top, 655px Left 308px Top, 690px Left 29...
# zuidyy                                                                     NaN
# zxbwkz                              27px Top, 516px Left 439px Top, 713px Left
# zymjlf                       340px Top, 1297px Left 369px Top, 1221px Left ...
#
# Zone Name                                                                Trust  \
# Participant Completion Code
# aaqmxl                                                   172px Top, 640px Left
# acogtt                                                                     NaN
# adixob                                                     96px Top, 19px Left
# adusps                               154px Top, 257px Left 95px Top, 56px Left
# adxtsl                                                                     NaN
# ...                                                                        ...
# zoafdf                                                   263px Top, 291px Left
# zotpxg                                                   406px Top, 333px Left
# zuidyy                             501px Top, 188px Left 470px Top, 140px Left
# zxbwkz                                                   132px Top, 529px Left
# zymjlf                       208px Top, 1117px Left 145px Top, 1143px Left ...
#
# Zone Name                                                               Voting
# Participant Completion Code
# aaqmxl                                                   342px Top, 653px Left
# acogtt                                                                     NaN
# adixob                                                     127px Top, 6px Left
# adusps                                                    56px Top, 569px Left
# adxtsl                       126px Top, 100px Left 119px Top, 167px Left 11...
# ...                                                                        ...
# zoafdf                                                   460px Top, 381px Left
# zotpxg                       169px Top, 492px Left 175px Top, 432px Left 16...
# zuidyy                       284px Top, 66px Left 309px Top, 141px Left 255...
# zxbwkz                                                   330px Top, 528px Left
# zymjlf                       133px Top, 1075px Left 18px Top, 1083px Left 6...
#
# [436 rows x 16 columns]

# %%
# for loop to replace NaN with default values. 
zone_name = df_default_values['Zone Name'].to_list()
coordinates = df_default_values['Response'].to_list()

for i in range(df_taskSpAM.shape[0]):
  for j in range(df_taskSpAM.shape[1]):
    if pd.isna(df_taskSpAM.iloc[i,j]):
      index = zone_name.index(df_taskSpAM.columns[j])
      df_taskSpAM.iloc[i,j] = coordinates[index]

# Select the last coordinate input
df_taskSpAM = df_taskSpAM.apply(lambda x: x.str.split(',').str[-1])
display(df_taskSpAM)
# Out:
# Zone Name                                                                Anger  \
# Participant Completion Code
# aaqmxl                             464px Top, 498px Left 505px Top, 498px Left
# acogtt                               119px Top, 22px Left 111px Top, 31px Left
# adixob                                                   116px Top, 142px Left
# adusps                             156px Top, 297px Left 162px Top, 114px Left
# adxtsl                                                   364px Top, 305px Left
# ...                                                                        ...
# zoafdf                                                   100px Top, 238px Left
# zotpxg                       177px Top, 769px Left 165px Top, 761px Left 20...
# zuidyy                              252px Top, 144px Left 71px Top, 142px Left
# zxbwkz                       55px Top, 382px Left 49px Top, 381px Left 48px...
# zymjlf                       763px Top, 831px Left 864px Top, 805px Left 82...
#
# Zone Name                                                        Conservatives  \
# Participant Completion Code
# aaqmxl                       233px Top, 939px Left 238px Top, 935px Left 22...
# acogtt                                                    439px Top, 21px Left
# adixob                                                    30px Top, 200px Left
# adusps                                                   114px Top, 599px Left
# adxtsl                                                    30px Top, 200px Left
# ...                                                                        ...
# zoafdf                                                    11px Top, 443px Left
# zotpxg                       165px Top, 325px Left 178px Top, 222px Left 21...
# zuidyy                                                    30px Top, 200px Left
# zxbwkz                               50px Top, 649px Left 49px Top, 654px Left
# zymjlf                       117px Top, 802px Left 93px Top, 804px Left 66p...
#
# Zone Name                                                                 Fear  \
# Participant Completion Code
# aaqmxl                                                   175px Top, 320px Left
# acogtt                                                    175px Top, 24px Left
# adixob                                                    54px Top, 142px Left
# adusps                             152px Top, 378px Left 127px Top, 220px Left
# adxtsl                       248px Top, 390px Left 244px Top, 224px Left 18...
# ...                                                                        ...
# zoafdf                                                   172px Top, 500px Left
# zotpxg                             293px Top, 230px Left 191px Top, 135px Left
# zuidyy                               132px Top, 25px Left 139px Top, 27px Left
# zxbwkz                                                   197px Top, 275px Left
# zymjlf                             667px Top, 421px Left 200px Top, 939px Left
#
# Zone Name                                                          Firefighter  \
# Participant Completion Code
# aaqmxl                             233px Top, 496px Left 108px Top, 491px Left
# acogtt                                                     32px Top, 41px Left
# adixob                                                     32px Top, 41px Left
# adusps                       45px Top, 53px Left 52px Top, 6px Left 84px To...
# adxtsl                       463px Top, 313px Left 444px Top, -14px Left 33...
# ...                                                                        ...
# zoafdf                                                    44px Top, 420px Left
# zotpxg                       92px Top, 321px Left 174px Top, 437px Left 19p...
# zuidyy                       44px Top, 44px Left 39px Top, 29px Left 24px T...
# zxbwkz                             382px Top, 398px Left 381px Top, 403px Left
# zymjlf                       194px Top, 731px Left 197px Top, 1298px Left 8...
#
# Zone Name                                                           Healthcare  \
# Participant Completion Code
# aaqmxl                                                   490px Top, 181px Left
# acogtt                                                    679px Top, 40px Left
# adixob                                 280px Top, 22px Left 70px Top, 6px Left
# adusps                                                    290px Top, -5px Left
# adxtsl                                386px Top, 87px Left 539px Top, 7px Left
# ...                                                                        ...
# zoafdf                             334px Top, 398px Left 285px Top, 481px Left
# zotpxg                       290px Top, 563px Left 289px Top, 563px Left 28...
# zuidyy                                                    679px Top, 40px Left
# zxbwkz                               428px Top, 17px Left 66px Top, 530px Left
# zymjlf                       755px Top, 1265px Left 855px Top, 1218px Left ...
#
# Zone Name                                                          Immigration  \
# Participant Completion Code
# aaqmxl                                                    216px Top, 61px Left
# acogtt                                                    125px Top, 39px Left
# adixob                                43px Top, 28px Left 48px Top, 131px Left
# adusps                                                    62px Top, 454px Left
# adxtsl                                                    125px Top, 39px Left
# ...                                                                        ...
# zoafdf                                                    94px Top, 457px Left
# zotpxg                             269px Top, 462px Left 287px Top, 446px Left
# zuidyy                               371px Top, 31px Left 369px Top, 29px Left
# zxbwkz                                                    38px Top, 275px Left
# zymjlf                       29px Top, 1075px Left 53px Top, 1087px Left 14...
#
# Zone Name                                                                  Joy  \
# Participant Completion Code
# aaqmxl                       377px Top, 308px Left 394px Top, 329px Left 36...
# acogtt                                                    494px Top, 41px Left
# adixob                                                    124px Top, 29px Left
# adusps                               170px Top, 292px Left 71px Top, 60px Left
# adxtsl                       332px Top, 34px Left 333px Top, 29px Left 327p...
# ...                                                                        ...
# zoafdf                                                   104px Top, 249px Left
# zotpxg                                                   408px Top, 592px Left
# zuidyy                               306px Top, -2px Left 295px Top, 30px Left
# zxbwkz                                                   114px Top, 774px Left
# zymjlf                       294px Top, 1260px Left 413px Top, 1574px Left ...
#
# Zone Name                                                             Liberals  \
# Participant Completion Code
# aaqmxl                             256px Top, 148px Left 277px Top, 180px Left
# acogtt                                                    190px Top, 34px Left
# adixob                                                     89px Top, 12px Left
# adusps                                                   124px Top, 516px Left
# adxtsl                       43px Top, 293px Left 40px Top, 290px Left 46px...
# ...                                                                        ...
# zoafdf                                                   457px Top, 307px Left
# zotpxg                       285px Top, 350px Left 275px Top, 327px Left 30...
# zuidyy                               489px Top, 16px Left 176px Top, 24px Left
# zxbwkz                                                   121px Top, 278px Left
# zymjlf                             83px Top, 1279px Left 46px Top, 1328px Left
#
# Zone Name                                                             Love  \
# Participant Completion Code
# aaqmxl                                               186px Top, 779px Left
# acogtt                                                403px Top, 41px Left
# adixob                                                106px Top, 16px Left
# adusps                          173px Top, 300px Left 54px Top, 148px Left
# adxtsl                                                403px Top, 41px Left
# ...                                                                    ...
# zoafdf                                               337px Top, 349px Left
# zotpxg                                               406px Top, 458px Left
# zuidyy                                                408px Top, 23px Left
# zxbwkz                         276px Top, 754px Left 285px Top, 777px Left
# zymjlf                       249px Top, 1344px Left 230px Top, 1407px Left
#
# Zone Name                                                            Neighbors  \
# Participant Completion Code
# aaqmxl                       199px Top, 442px Left 324px Top, 496px Left 37...
# acogtt                                                    313px Top, 28px Left
# adixob                                                     71px Top, 38px Left
# adusps                             287px Top, 319px Left 297px Top, 274px Left
# adxtsl                             201px Top, 479px Left 427px Top, 368px Left
# ...                                                                        ...
# zoafdf                                                   253px Top, 532px Left
# zotpxg                             121px Top, 243px Left 426px Top, 711px Left
# zuidyy                             375px Top, 154px Left 108px Top, 141px Left
# zxbwkz                       113px Top, 263px Left 124px Top, 276px Left 19...
# zymjlf                       313px Top, 1204px Left 304px Top, 1498px Left ...
#
# Zone Name                                                               Police  \
# Participant Completion Code
# aaqmxl                             199px Top, 494px Left 200px Top, 491px Left
# acogtt                                                    251px Top, 19px Left
# adixob                                                    88px Top, 150px Left
# adusps                                                   305px Top, 513px Left
# adxtsl                       476px Top, 438px Left 483px Top, 83px Left 479...
# ...                                                                        ...
# zoafdf                                                   398px Top, 445px Left
# zotpxg                       174px Top, 597px Left 186px Top, 521px Left 17...
# zuidyy                               104px Top, 144px Left 56px Top, 25px Left
# zxbwkz                             409px Top, 543px Left 425px Top, 404px Left
# zymjlf                       558px Top, 1034px Left 700px Top, 1033px Left ...
#
# Zone Name                                                             Religion  \
# Participant Completion Code
# aaqmxl                                                   301px Top, 852px Left
# acogtt                                                    324px Top, 28px Left
# adixob                                                   111px Top, 159px Left
# adusps                                                   277px Top, 715px Left
# adxtsl                                                   310px Top, 207px Left
# ...                                                                        ...
# zoafdf                                                   394px Top, 541px Left
# zotpxg                       165px Top, 674px Left 172px Top, 655px Left 16...
# zuidyy                                                      9px Top, 24px Left
# zxbwkz                                                    33px Top, 773px Left
# zymjlf                       353px Top, 723px Left 361px Top, 804px Left 33...
#
# Zone Name                                                              Sadness  \
# Participant Completion Code
# aaqmxl                                                   112px Top, 294px Left
# acogtt                                                    219px Top, 43px Left
# adixob                                                    81px Top, 137px Left
# adusps                             191px Top, 290px Left 105px Top, 132px Left
# adxtsl                                                    219px Top, 43px Left
# ...                                                                        ...
# zoafdf                                                   179px Top, 244px Left
# zotpxg                             362px Top, 133px Left 293px Top, 209px Left
# zuidyy                                                    253px Top, 25px Left
# zxbwkz                             191px Top, 763px Left 204px Top, 772px Left
# zymjlf                       282px Top, 564px Left 565px Top, 409px Left 51...
#
# Zone Name                                                              Science  \
# Participant Completion Code
# aaqmxl                       333px Top, 149px Left 411px Top, 182px Left 40...
# acogtt                                                    514px Top, 15px Left
# adixob                                                    116px Top, 25px Left
# adusps                                                    336px Top, 47px Left
# adxtsl                              520px Top, 151px Left 564px Top, 90px Left
# ...                                                                        ...
# zoafdf                                                   525px Top, 625px Left
# zotpxg                       293px Top, 655px Left 308px Top, 690px Left 29...
# zuidyy                                                   588px Top, 206px Left
# zxbwkz                              27px Top, 516px Left 439px Top, 713px Left
# zymjlf                       340px Top, 1297px Left 369px Top, 1221px Left ...
#
# Zone Name                                                                Trust  \
# Participant Completion Code
# aaqmxl                                                   172px Top, 640px Left
# acogtt                                                    311px Top, 44px Left
# adixob                                                     96px Top, 19px Left
# adusps                               154px Top, 257px Left 95px Top, 56px Left
# adxtsl                                                    311px Top, 44px Left
# ...                                                                        ...
# zoafdf                                                   263px Top, 291px Left
# zotpxg                                                   406px Top, 333px Left
# zuidyy                             501px Top, 188px Left 470px Top, 140px Left
# zxbwkz                                                   132px Top, 529px Left
# zymjlf                       208px Top, 1117px Left 145px Top, 1143px Left ...
#
# Zone Name                                                               Voting
# Participant Completion Code
# aaqmxl                                                   342px Top, 653px Left
# acogtt                                                    588px Top, 40px Left
# adixob                                                     127px Top, 6px Left
# adusps                                                    56px Top, 569px Left
# adxtsl                       126px Top, 100px Left 119px Top, 167px Left 11...
# ...                                                                        ...
# zoafdf                                                   460px Top, 381px Left
# zotpxg                       169px Top, 492px Left 175px Top, 432px Left 16...
# zuidyy                       284px Top, 66px Left 309px Top, 141px Left 255...
# zxbwkz                                                   330px Top, 528px Left
# zymjlf                       133px Top, 1075px Left 18px Top, 1083px Left 6...
#
# [436 rows x 16 columns]

# %%
x = zone_name.index(df_taskSpAM.columns[j])
print(coordinates[x]), print(coordinates)
# Out:
# 679px Top, 40px Left
# ['679px Top, 205px Left', '679px Top, 40px Left', '588px Top, 40px Left', '588px Top, 206px Left', '498px Top, 207px Left', '494px Top, 41px Left', '406px Top, 206px Left', '403px Top, 41px Left', '310px Top, 207px Left', '311px Top, 44px Left', '220px Top, 209px Left', '219px Top, 43px Left', '126px Top, 207px Left', '125px Top, 39px Left', '30px Top, 200px Left', '32px Top, 41px Left']
# (None, None)

# %%
df_taskPRaM
# Out:
# Zone Name                                                                Anger  \
# Participant Completion Code
# aaqmxl                          [464px Top, 498px Left, 505px Top, 498px Left]
# acogtt                            [119px Top, 22px Left, 111px Top, 31px Left]
# adixob                                                 [116px Top, 142px Left]
# adusps                          [156px Top, 297px Left, 162px Top, 114px Left]
# adxtsl                                                 [364px Top, 305px Left]
# ...                                                                        ...
# zoafdf                                                 [100px Top, 238px Left]
# zotpxg                       [177px Top, 769px Left, 165px Top, 761px Left,...
# zuidyy                           [252px Top, 144px Left, 71px Top, 142px Left]
# zxbwkz                       [55px Top, 382px Left, 49px Top, 381px Left, 4...
# zymjlf                       [763px Top, 831px Left, 864px Top, 805px Left,...
#
# Zone Name                                                        Conservatives  \
# Participant Completion Code
# aaqmxl                       [233px Top, 939px Left, 238px Top, 935px Left,...
# acogtt                                                  [439px Top, 21px Left]
# adixob                                                                     NaN
# adusps                                                 [114px Top, 599px Left]
# adxtsl                                                                     NaN
# ...                                                                        ...
# zoafdf                                                  [11px Top, 443px Left]
# zotpxg                       [165px Top, 325px Left, 178px Top, 222px Left,...
# zuidyy                                                                     NaN
# zxbwkz                            [50px Top, 649px Left, 49px Top, 654px Left]
# zymjlf                       [117px Top, 802px Left, 93px Top, 804px Left, ...
#
# Zone Name                                                                 Fear  \
# Participant Completion Code
# aaqmxl                                                 [175px Top, 320px Left]
# acogtt                                                  [175px Top, 24px Left]
# adixob                                                  [54px Top, 142px Left]
# adusps                          [152px Top, 378px Left, 127px Top, 220px Left]
# adxtsl                       [248px Top, 390px Left, 244px Top, 224px Left,...
# ...                                                                        ...
# zoafdf                                                 [172px Top, 500px Left]
# zotpxg                          [293px Top, 230px Left, 191px Top, 135px Left]
# zuidyy                            [132px Top, 25px Left, 139px Top, 27px Left]
# zxbwkz                                                 [197px Top, 275px Left]
# zymjlf                          [667px Top, 421px Left, 200px Top, 939px Left]
#
# Zone Name                                                          Firefighter  \
# Participant Completion Code
# aaqmxl                          [233px Top, 496px Left, 108px Top, 491px Left]
# acogtt                                                                     NaN
# adixob                                                                     NaN
# adusps                       [45px Top, 53px Left, 52px Top, 6px Left, 84px...
# adxtsl                       [463px Top, 313px Left, 444px Top, -14px Left,...
# ...                                                                        ...
# zoafdf                                                  [44px Top, 420px Left]
# zotpxg                       [92px Top, 321px Left, 174px Top, 437px Left, ...
# zuidyy                       [44px Top, 44px Left, 39px Top, 29px Left, 24p...
# zxbwkz                          [382px Top, 398px Left, 381px Top, 403px Left]
# zymjlf                       [194px Top, 731px Left, 197px Top, 1298px Left...
#
# Zone Name                                                           Healthcare  \
# Participant Completion Code
# aaqmxl                                                 [490px Top, 181px Left]
# acogtt                                                                     NaN
# adixob                              [280px Top, 22px Left, 70px Top, 6px Left]
# adusps                                                  [290px Top, -5px Left]
# adxtsl                             [386px Top, 87px Left, 539px Top, 7px Left]
# ...                                                                        ...
# zoafdf                          [334px Top, 398px Left, 285px Top, 481px Left]
# zotpxg                       [290px Top, 563px Left, 289px Top, 563px Left,...
# zuidyy                                                                     NaN
# zxbwkz                            [428px Top, 17px Left, 66px Top, 530px Left]
# zymjlf                       [755px Top, 1265px Left, 855px Top, 1218px Lef...
#
# Zone Name                                                          Immigration  \
# Participant Completion Code
# aaqmxl                                                  [216px Top, 61px Left]
# acogtt                                                                     NaN
# adixob                             [43px Top, 28px Left, 48px Top, 131px Left]
# adusps                                                  [62px Top, 454px Left]
# adxtsl                                                                     NaN
# ...                                                                        ...
# zoafdf                                                  [94px Top, 457px Left]
# zotpxg                          [269px Top, 462px Left, 287px Top, 446px Left]
# zuidyy                            [371px Top, 31px Left, 369px Top, 29px Left]
# zxbwkz                                                  [38px Top, 275px Left]
# zymjlf                       [29px Top, 1075px Left, 53px Top, 1087px Left,...
#
# Zone Name                                                                  Joy  \
# Participant Completion Code
# aaqmxl                       [377px Top, 308px Left, 394px Top, 329px Left,...
# acogtt                                                                     NaN
# adixob                                                  [124px Top, 29px Left]
# adusps                            [170px Top, 292px Left, 71px Top, 60px Left]
# adxtsl                       [332px Top, 34px Left, 333px Top, 29px Left, 3...
# ...                                                                        ...
# zoafdf                                                 [104px Top, 249px Left]
# zotpxg                                                 [408px Top, 592px Left]
# zuidyy                            [306px Top, -2px Left, 295px Top, 30px Left]
# zxbwkz                                                 [114px Top, 774px Left]
# zymjlf                       [294px Top, 1260px Left, 413px Top, 1574px Lef...
#
# Zone Name                                                             Liberals  \
# Participant Completion Code
# aaqmxl                          [256px Top, 148px Left, 277px Top, 180px Left]
# acogtt                                                  [190px Top, 34px Left]
# adixob                                                   [89px Top, 12px Left]
# adusps                                                 [124px Top, 516px Left]
# adxtsl                       [43px Top, 293px Left, 40px Top, 290px Left, 4...
# ...                                                                        ...
# zoafdf                                                 [457px Top, 307px Left]
# zotpxg                       [285px Top, 350px Left, 275px Top, 327px Left,...
# zuidyy                            [489px Top, 16px Left, 176px Top, 24px Left]
# zxbwkz                                                 [121px Top, 278px Left]
# zymjlf                          [83px Top, 1279px Left, 46px Top, 1328px Left]
#
# Zone Name                                                                Love  \
# Participant Completion Code
# aaqmxl                                                [186px Top, 779px Left]
# acogtt                                                                    NaN
# adixob                                                 [106px Top, 16px Left]
# adusps                          [173px Top, 300px Left, 54px Top, 148px Left]
# adxtsl                                                                    NaN
# ...                                                                       ...
# zoafdf                                                [337px Top, 349px Left]
# zotpxg                                                [406px Top, 458px Left]
# zuidyy                                                 [408px Top, 23px Left]
# zxbwkz                         [276px Top, 754px Left, 285px Top, 777px Left]
# zymjlf                       [249px Top, 1344px Left, 230px Top, 1407px Left]
#
# Zone Name                                                            Neighbors  \
# Participant Completion Code
# aaqmxl                       [199px Top, 442px Left, 324px Top, 496px Left,...
# acogtt                                                  [313px Top, 28px Left]
# adixob                                                   [71px Top, 38px Left]
# adusps                          [287px Top, 319px Left, 297px Top, 274px Left]
# adxtsl                          [201px Top, 479px Left, 427px Top, 368px Left]
# ...                                                                        ...
# zoafdf                                                 [253px Top, 532px Left]
# zotpxg                          [121px Top, 243px Left, 426px Top, 711px Left]
# zuidyy                          [375px Top, 154px Left, 108px Top, 141px Left]
# zxbwkz                       [113px Top, 263px Left, 124px Top, 276px Left,...
# zymjlf                       [313px Top, 1204px Left, 304px Top, 1498px Lef...
#
# Zone Name                                                               Police  \
# Participant Completion Code
# aaqmxl                          [199px Top, 494px Left, 200px Top, 491px Left]
# acogtt                                                  [251px Top, 19px Left]
# adixob                                                  [88px Top, 150px Left]
# adusps                                                 [305px Top, 513px Left]
# adxtsl                       [476px Top, 438px Left, 483px Top, 83px Left, ...
# ...                                                                        ...
# zoafdf                                                 [398px Top, 445px Left]
# zotpxg                       [174px Top, 597px Left, 186px Top, 521px Left,...
# zuidyy                            [104px Top, 144px Left, 56px Top, 25px Left]
# zxbwkz                          [409px Top, 543px Left, 425px Top, 404px Left]
# zymjlf                       [558px Top, 1034px Left, 700px Top, 1033px Lef...
#
# Zone Name                                                             Religion  \
# Participant Completion Code
# aaqmxl                                                 [301px Top, 852px Left]
# acogtt                                                  [324px Top, 28px Left]
# adixob                                                 [111px Top, 159px Left]
# adusps                                                 [277px Top, 715px Left]
# adxtsl                                                                     NaN
# ...                                                                        ...
# zoafdf                                                 [394px Top, 541px Left]
# zotpxg                       [165px Top, 674px Left, 172px Top, 655px Left,...
# zuidyy                                                    [9px Top, 24px Left]
# zxbwkz                                                  [33px Top, 773px Left]
# zymjlf                       [353px Top, 723px Left, 361px Top, 804px Left,...
#
# Zone Name                                                              Sadness  \
# Participant Completion Code
# aaqmxl                                                 [112px Top, 294px Left]
# acogtt                                                                     NaN
# adixob                                                  [81px Top, 137px Left]
# adusps                          [191px Top, 290px Left, 105px Top, 132px Left]
# adxtsl                                                                     NaN
# ...                                                                        ...
# zoafdf                                                 [179px Top, 244px Left]
# zotpxg                          [362px Top, 133px Left, 293px Top, 209px Left]
# zuidyy                                                  [253px Top, 25px Left]
# zxbwkz                          [191px Top, 763px Left, 204px Top, 772px Left]
# zymjlf                       [282px Top, 564px Left, 565px Top, 409px Left,...
#
# Zone Name                                                              Science  \
# Participant Completion Code
# aaqmxl                       [333px Top, 149px Left, 411px Top, 182px Left,...
# acogtt                                                  [514px Top, 15px Left]
# adixob                                                  [116px Top, 25px Left]
# adusps                                                  [336px Top, 47px Left]
# adxtsl                           [520px Top, 151px Left, 564px Top, 90px Left]
# ...                                                                        ...
# zoafdf                                                 [525px Top, 625px Left]
# zotpxg                       [293px Top, 655px Left, 308px Top, 690px Left,...
# zuidyy                                                                     NaN
# zxbwkz                           [27px Top, 516px Left, 439px Top, 713px Left]
# zymjlf                       [340px Top, 1297px Left, 369px Top, 1221px Lef...
#
# Zone Name                                                                Trust  \
# Participant Completion Code
# aaqmxl                                                 [172px Top, 640px Left]
# acogtt                                                                     NaN
# adixob                                                   [96px Top, 19px Left]
# adusps                            [154px Top, 257px Left, 95px Top, 56px Left]
# adxtsl                                                                     NaN
# ...                                                                        ...
# zoafdf                                                 [263px Top, 291px Left]
# zotpxg                                                 [406px Top, 333px Left]
# zuidyy                          [501px Top, 188px Left, 470px Top, 140px Left]
# zxbwkz                                                 [132px Top, 529px Left]
# zymjlf                       [208px Top, 1117px Left, 145px Top, 1143px Lef...
#
# Zone Name                                                               Voting
# Participant Completion Code
# aaqmxl                                                 [342px Top, 653px Left]
# acogtt                                                                     NaN
# adixob                                                   [127px Top, 6px Left]
# adusps                                                  [56px Top, 569px Left]
# adxtsl                       [126px Top, 100px Left, 119px Top, 167px Left,...
# ...                                                                        ...
# zoafdf                                                 [460px Top, 381px Left]
# zotpxg                       [169px Top, 492px Left, 175px Top, 432px Left,...
# zuidyy                       [284px Top, 66px Left, 309px Top, 141px Left, ...
# zxbwkz                                                 [330px Top, 528px Left]
# zymjlf                       [133px Top, 1075px Left, 18px Top, 1083px Left...
#
# [436 rows x 16 columns]

# %%
#Isolate Pivot dataframes
df_demographic = df_demographic.pivot(index = 'Participant Completion Code', columns = ['Question Key'], values = ['Response']) #Demographics
#display(df_demographic)

df_EthId = df_EthId.pivot(index = 'Participant Completion Code', columns = ['Question Key'], values = ['Response']) #Ethnic Identity
#display(df_EthId)

df_MIBI = df_MIBI.pivot(index = 'Participant Completion Code', columns = ['Question Key'], values = ['Response']) #Multidimensional Inventory of Black Identity
#display(df_MIBI)

df_News = df_News.pivot(index = 'Participant Completion Code', columns = ['Question Key'], values = ['Response']) #News Consumption
#display(df_News)

df_GRDiscrim = df_GRDiscrim.pivot(index = 'Participant Completion Code', columns = ['Question Key'], values = ['Response']) #Gender/Racial Discrimination
#display(df_GRDiscrim)

df_ConExposure = df_ConExposure.pivot(index = 'Participant Completion Code', columns = ['Question Key'], values = ['Response']) #Concept Exposure
#display(df_ConExposure)

df_ConFeeling = df_ConFeeling.pivot(index = 'Participant Completion Code', columns = ['Question Key'], values = ['Response']) #Concept Feeling
#display(df_ConFeeling)

df_ConInteraction = df_ConInteraction.pivot(index = 'Participant Completion Code', columns = ['Question Key'], values = ['Response']) #Concept Interaction
#display(df_ConInteraction)

df_SDO = df_SDO.pivot(index = 'Participant Completion Code', columns = ['Question Key'], values = ['Response']) #Social Dominance Orientation
#display(df_SDO)

#TASKS:
#TODO: Take last mask out last instance of each concepts. If no isntance is present then use default coordinate. Flag participants that did not move at least half of the concepts (i.e., there are no entries)
#df_taskSpAM_test = df_taskSpAM.pivot(index = 'Participant Completion Code', columns = ['Zone Name'], values = ['Response']) #SpAM
#df_taskSpAM_test = df_taskSpAM_test.groupby(level=0).last()
#display(df_taskSpAM_test)

# Old code runs to "ValueError: Index contains duplicate entries, cannot reshape" isssue.
# df_taskPRaM = df_taskPRaM.pivot(index = ['Participant Completion Code'], columns = ['Pair'], values = ['Response']) #PRaM
# #display(df_taskPRaM)

#Solution
# group values by index column and aggregating the Response values as list. 
df_taskPRaM = df_taskPRaM.groupby(['Participant Completion Code', 'Pair'])['Response'].agg(list).reset_index()
df_taskPRaM = df_taskPRaM.pivot(index='Participant Completion Code', columns='Pair', values='Response')

# Run the following function to convert Response values from list to float.
df_taskPRaM = df_taskPRaM.applymap(convert_to_float)
#display(df_taskPRaM)

# %%
#Push to Lab GitHub !!!
#NOTE: These credentials should be configured to user's lab GitHub
#If user is part of ExCaLBBR Lab then ask Roberto for access
# !git config --global user.name "nmossazg12" #"YOUR CREDIENTIALS HERE" 
# !git config --global user.email "anahom12@gmail.com" #"YOUR CREDIENTIALS HERE"
# !git config --global user.password "#Gezabanda123" #"YOUR CREDIENTIALS HERE"

token = ''
username_organization = ''
repo = ''
outputDir = ''

# %%
#Clone repository and move created files into output directory
# !git clone https://{token}@github.com/{username_organization}/{repo}
# Out:
# Cloning into 'github.com'...
# fatal: repository 'https://github.com//' not found

# %%
#Convert all files to csv
df_check.to_csv('check.csv')
df_demographic.to_csv('demographic.csv')
df_taskRGN.to_csv('taskRGN.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-201-b82e6df96966> in <module>
#       1 #Convert all files to csv
# ----> 2 df_check.to_csv('check.csv')
#       3 df_demographic.to_csv('demographic.csv')
#       4 df_taskRGN.to_csv('taskRGN.csv')
#
# NameError: name 'df_check' is not defined

# %%
#Move files to Clone repository
# !mv check.csv {repo}/{outputDir}
# !mv demographic.csv {repo}/{outputDir}
# !mv taskRGN.csv {repo}/{outputDir}

# %%
#Move to principle dir, commit, and push changes
# %cd {repo}
# !git add --all
# !git commit -a -m "Fixed issues with Isolate relevant columns: PRaM and SPaM"
# !git push origin
